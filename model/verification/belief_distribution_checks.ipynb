# %% [markdown]
# # Checks of the resulting Belief Distributions
# For each of the three Belief Update Functions (i.e., DEFFUANT, SAMPLE, SIT), a couple of experiments are run in this notebook to test the model behavior.

# %%
# General Imports
from utils_belief_distribution_checks import *
from model.enums import *
from model.misinfo_model import *
import pandas as pd
import seaborn as sns

# %%
# Test
list(MediaLiteracy)
# Out:
# [<MediaLiteracy.LOW: 3>, <MediaLiteracy.HIGH: 30>]

# %% [markdown]
# # 1. DEFFUANT

# %%
belief_update_fn = BeliefUpdate.DEFFUANT

# %%
# all OFF
data = run_experiment(mlit_select=0.0, del_t=0.0, rank_t=0.0, rank_punish=-0.0, strikes_t=0.0, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="DEFFUANT – all OFF", y_max=300)

# %%
# all MEDIUM
data = run_experiment(mlit_select=0.2, del_t=0.1, rank_t=0.2, rank_punish=-0.2, strikes_t=0.1, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="DEFFUANT – all MEDIUM", y_max=300)

# %%
# all HIGH
data = run_experiment(mlit_select=1.0, del_t=0.5, rank_t=0.5, rank_punish=-1.0, strikes_t=0.5, belief_update=belief_update_fn)
create_subplot(data=data, title="DEFFUANT – all HIGH", y_max=300)

# %% [markdown]
# ### 1-at-time: each lever individually STRONG

# %%
# mlit_select STRONG
data = run_experiment(mlit_select=1.0, del_t=0.05, rank_t=0.1, rank_punish=-0.1, strikes_t=0.05, belief_update=belief_update_fn)
create_subplot(data=data, title="DEFFUANT – mlit_select strong", y_max=300)

# %%
# del_t STRONG
data = run_experiment(mlit_select=0.1, del_t=0.5, rank_t=0.1, rank_punish=-0.1, strikes_t=0.05, belief_update=belief_update_fn)
create_subplot(data=data, title="DEFFUANT – del_t strong", y_max=300)

# %%
# rank_t STRONG
data = run_experiment(mlit_select=0.1, del_t=0.05, rank_t=0.5, rank_punish=-0.1, strikes_t=0.05, belief_update=belief_update_fn)
create_subplot(data=data, title="DEFFUANT – rank_t strong", y_max=300)

# %%
# rank_punish STRONG
data = run_experiment(mlit_select=0.1, del_t=0.05, rank_t=0.1, rank_punish=-1.0, strikes_t=0.05, belief_update=belief_update_fn)
create_subplot(data=data, title="DEFFUANT – rank_punish strong", y_max=300)

# %%
# strikes_t STRONG
data = run_experiment(mlit_select=0.1, del_t=0.05, rank_t=0.1, rank_punish=-0.1, strikes_t=0.5, belief_update=belief_update_fn)
create_subplot(data=data, title="DEFFUANT – strikes_t strong", y_max=300)

# %% [markdown]
# ## 2. SAMPLE

# %%
belief_update_fn = BeliefUpdate.SAMPLE

# %%
# all OFF
data = run_experiment(mlit_select=0.0, del_t=0.0, rank_t=0.0, rank_punish=-0.0, strikes_t=0.0, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="SAMPLE – all OFF", y_max=300)

# %%
# all MEDIUM
data = run_experiment(mlit_select=0.2, del_t=0.1, rank_t=0.2, rank_punish=-0.2, strikes_t=0.1, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="SAMPLE – all MEDIUM", y_max=300)

# %%
# all HIGH
data = run_experiment(mlit_select=1.0, del_t=0.5, rank_t=0.5, rank_punish=-1.0, strikes_t=0.5, belief_update=belief_update_fn)
create_subplot(data=data, title="SAMPLE – all HIGH", y_max=300)

# %% [markdown]
# ### 1-at-time: each lever individually STRONG

# %%
# mlit_select STRONG
data = run_experiment(mlit_select=1.0, del_t=0.05, rank_t=0.1, rank_punish=-0.1, strikes_t=0.05,
                      belief_update=belief_update_fn)
create_subplot(data=data, title="SAMPLE – mlit_select strong", y_max=300)

# %%
# del_t STRONG
data = run_experiment(mlit_select=0.1, del_t=0.5, rank_t=0.1, rank_punish=-0.1, strikes_t=0.05,
                      belief_update=belief_update_fn)
create_subplot(data=data, title="SAMPLE – del_t strong", y_max=300)

# %%
# rank_t STRONG
data = run_experiment(mlit_select=0.1, del_t=0.05, rank_t=0.5, rank_punish=-0.1, strikes_t=0.05,
                      belief_update=belief_update_fn)
create_subplot(data=data, title="SAMPLE – rank_t strong", y_max=300)

# %%
# rank_punish STRONG
data = run_experiment(mlit_select=0.1, del_t=0.05, rank_t=0.1, rank_punish=-1.0, strikes_t=0.05,
                      belief_update=belief_update_fn)
create_subplot(data=data, title="SAMPLE – rank_punish strong", y_max=300)

# %%
# strikes_t STRONG
data = run_experiment(mlit_select=0.1, del_t=0.05, rank_t=0.1, rank_punish=-0.1, strikes_t=0.5,
                      belief_update=belief_update_fn)
create_subplot(data=data, title="SAMPLE – strikes_t strong", y_max=300)

# %% [markdown]
# ## 3. SIT

# %%
belief_update_fn = BeliefUpdate.SIT

# %%
# all OFF
data = run_experiment(mlit_select=0.0, del_t=0.0, rank_t=0.0, rank_punish=-0.0, strikes_t=0.0, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="SIT – all OFF", y_max=300)

# %%
# all MEDIUM
data = run_experiment(mlit_select=0.2, del_t=0.1, rank_t=0.2, rank_punish=-0.2, strikes_t=0.1, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="SIT – all MEDIUM", y_max=300)

# %%
# all HIGH
data = run_experiment(mlit_select=1.0, del_t=0.5, rank_t=0.5, rank_punish=-1.0, strikes_t=0.5, belief_update=belief_update_fn)
create_subplot(data=data, title="SIT – all HIGH", y_max=300)

# %% [markdown]
# ### 1-at-time: each lever individually STRONG

# %%
# mlit_select STRONG
data = run_experiment(mlit_select=1.0, del_t=0.05, rank_t=0.1, rank_punish=-0.1, strikes_t=0.05,
                      belief_update=belief_update_fn)
create_subplot(data=data, title="SIT – mlit_select strong", y_max=300)

# %%
# del_t STRONG
data = run_experiment(mlit_select=0.1, del_t=0.5, rank_t=0.1, rank_punish=-0.1, strikes_t=0.05,
                      belief_update=belief_update_fn)
create_subplot(data=data, title="SIT – del_t strong", y_max=300)

# %%
# rank_t STRONG
data = run_experiment(mlit_select=0.1, del_t=0.05, rank_t=0.5, rank_punish=-0.1, strikes_t=0.05,
                      belief_update=belief_update_fn)
create_subplot(data=data, title="SIT – rank_t strong", y_max=300)

# %%
# rank_punish STRONG
data = run_experiment(mlit_select=0.1, del_t=0.05, rank_t=0.1, rank_punish=-1.0, strikes_t=0.05,
                      belief_update=belief_update_fn)
create_subplot(data=data, title="SIT – rank_punish strong", y_max=300)

# %%
# strikes_t STRONG
data = run_experiment(mlit_select=0.1, del_t=0.05, rank_t=0.1, rank_punish=-0.1, strikes_t=0.5,
                      belief_update=belief_update_fn)
create_subplot(data=data, title="SIT – strikes_t strong", y_max=300)

# %% [markdown]
# # ––––––––––––––––––––––––––– Agent Ratios –––––––––––––––––––––––––––
#
# ## 1. DEFFUANT

# %% [markdown]
# ## Only NormalUsers, all levers OFF

# %%
belief_update_fn = BeliefUpdate.DEFFUANT

# %%
data = run_experiment(mlit_select=0.0, del_t=0.0, rank_t=0.0, rank_punish=-0.0, strikes_t=0.0, belief_update=belief_update_fn, ratio_normal_user=1.0)
create_subplot(data=data, title="DEFFUANT – Only NormalUsers, all levers OFF", y_max=300)

# %% [markdown]
# ## Only Disinformers, all levers OFF

# %%
data = run_experiment(mlit_select=0.0, del_t=0.0, rank_t=0.0, rank_punish=-0.0, strikes_t=0.0, belief_update=belief_update_fn, ratio_normal_user=0.0)

create_subplot(data=data, title="DEFFUANT – Only Disinformers, all levers OFF")

# %% [markdown]
# ## Only NormalUsers, all levers HIGH

# %%
data = run_experiment(mlit_select=1.0, del_t=0.5, rank_t=0.5, rank_punish=-1.0, strikes_t=0.5, belief_update=belief_update_fn, ratio_normal_user=1.0)
create_subplot(data=data, title="DEFFUANT – Only NormalUsers, all levers HIGH", y_max=300)

# %% [markdown]
# ## 2. SAMPLE

# %%
belief_update_fn = BeliefUpdate.SAMPLE
data = run_experiment(mlit_select=0.0, del_t=0.0, rank_t=0.0, rank_punish=-0.0, strikes_t=0.0,
                      belief_update=belief_update_fn, ratio_normal_user=1.0)
create_subplot(data=data, title="SAMPLE – Only NormalUsers, all levers OFF", y_max=300)

# %%
## Only Disinformers, all levers OFF
data = run_experiment(mlit_select=0.0, del_t=0.0, rank_t=0.0, rank_punish=-0.0, strikes_t=0.0,
                      belief_update=belief_update_fn, ratio_normal_user=0.0)

create_subplot(data=data, title="SAMPLE – Only Disinformers, all levers OFF")

# %%
## Only NormalUsers, all levers HIGH
data = run_experiment(mlit_select=1.0, del_t=0.5, rank_t=0.5, rank_punish=-1.0, strikes_t=0.5,
                      belief_update=belief_update_fn, ratio_normal_user=1.0)
create_subplot(data=data, title="SAMPLE – Only NormalUsers, all levers HIGH", y_max=300)

# %% [markdown]
# ## 3. SIT

# %%
belief_update_fn = BeliefUpdate.SIT
data = run_experiment(mlit_select=0.0, del_t=0.0, rank_t=0.0, rank_punish=-0.0, strikes_t=0.0,
                      belief_update=belief_update_fn, ratio_normal_user=1.0)
create_subplot(data=data, title="SIT – Only NormalUsers, all levers OFF", y_max=300)

# %%
## Only Disinformers, all levers OFF
data = run_experiment(mlit_select=0.0, del_t=0.0, rank_t=0.0, rank_punish=-0.0, strikes_t=0.0,
                      belief_update=belief_update_fn, ratio_normal_user=0.0)

create_subplot(data=data, title="SIT – Only Disinformers, all levers OFF")

# %%
## Only NormalUsers, all levers HIGH
data = run_experiment(mlit_select=1.0, del_t=0.5, rank_t=0.5, rank_punish=-1.0, strikes_t=0.5,
                      belief_update=belief_update_fn, ratio_normal_user=1.0)
create_subplot(data=data, title="SIT – Only NormalUsers, all levers HIGH", y_max=300)

# %%
from ema_workbench import load_results
from ema_workbench.analysis import feature_scoring
import matplotlib.pyplot as plt
import seaborn as sns
from misinfo_model import MisinfoPy
from utils_dmdu import (get_levers, get_uncertainties)

# %% [markdown]
# # DEFFUANT Feature Scoring
# ### --> TODO:
#          1) Load Results from Open Exploration with SAMPLED policies instead (w/ DEFFUANT)
#          2) Create similar notebook for BeliefUpdateFns SAMPLE & SIT

# %%
# Indiv Max (DEFFUANT) – Levers
results = load_results('/Users/felicity/PycharmProjects/MisinfoPy/results/open_exploration_indiv_DEFFUANT')
exp, out = results

levers = [l.name for l in get_levers()]
exp_only_uncert = exp.drop(columns= levers + ["policy"])

sns.set_style("whitegrid")
fs = feature_scoring.get_feature_scores_all(exp_only_uncert, out)
sns.set(rc={'figure.figsize':(20, 15)})
sns.heatmap(fs, cmap="viridis", annot=True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# ...

# %%
# Indiv Max (DEFFUANT) – Uncertainties
results = load_results('/Users/felicity/PycharmProjects/MisinfoPy/results/open_exploration_indiv_DEFFUANT')
exp, out = results

uncertainties = [l.name for l in get_uncertainties()]
exp_only_levers = exp.drop(columns=uncertainties + ["policy"])

sns.set_style("whitegrid")
fs = feature_scoring.get_feature_scores_all(exp_only_levers, out)
sns.set(rc={'figure.figsize': (20, 15)})
sns.heatmap(fs, cmap="viridis", annot=True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# ...

# %% [markdown]
# # Checks of the resulting Belief Distributions
# For each of the three Belief Update Functions (i.e., DEFFUANT, SAMPLE, SIT), a couple of experiments are run in this notebook to test the model behavior.

# %%
# General Imports
from utils_belief_distribution_checks import *
from enums import *
from misinfo_model import *
import pandas as pd
import seaborn as sns

# %% [markdown]
# # 1. DEFFUANT

# %%
belief_update_fn = BeliefUpdate.DEFFUANT

# %%
# all OFF
data = run_experiment(mlit_select=0.0, rank_punish=-0.0, del_t=0.0, rank_t=0.0, strikes_t=0.0, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="DEFFUANT – all OFF")

# %%
# all MEDIUM
data = run_experiment(mlit_select=0.0, rank_punish=-0.0, del_t=0.0, rank_t=0.0, strikes_t=0.0, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="DEFFUANT – all MEDIUM")

# %%
# all HIGH

# %%
# 1-at-time: each lever individually on HIGH

# %% [markdown]
# ## 2. SAMPLE

# %%
belief_update_fn = BeliefUpdate.SAMPLE

# %%
# all OFF
data = run_experiment(mlit_select=0.0, rank_punish=-0.0, del_t=0.0, rank_t=0.0, strikes_t=0.0, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="SAMPLE – all OFF")

# %%
# all MEDIUM
# data = run_experiment(mlit_select=0.0, rank_punish=-0.0, del_t=0.0, rank_t=0.0, strikes_t=0.0, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="SAMPLE – all MEDIUM")

# %% [markdown]
# ## 3. SIT

# %%
belief_update_fn = BeliefUpdate.SIT

# %%
# all OFF
data = run_experiment(mlit_select=0.0, rank_punish=-0.0, del_t=0.0, rank_t=0.0, strikes_t=0.0, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="SIT – all OFF")

# %%
# all MEDIUM
# data = run_experiment(mlit_select=0.0, rank_punish=-0.0, del_t=0.0, rank_t=0.0, strikes_t=0.0, belief_update=belief_update_fn)

# %%
create_subplot(data=data, title="SIT – all MEDIUM")

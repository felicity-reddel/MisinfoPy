# %%
from ema_workbench import load_results
from ema_workbench.analysis import (
    pairs_plotting,
    feature_scoring
)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Indiv Max (DEFFUANT)
results = load_results('/Users/felicity/PycharmProjects/MisinfoPy/results/open_exploration_all_DEFFUANT')
exp, out = results

sns.set_style("whitegrid")
fig, axes = pairs_plotting.pairs_scatter(
    exp, out, group_by="policy", legend=True,
)
fig.set_size_inches(16, 16)
plt.show()

# %%
# Indiv Max (SAMPLE)
results = load_results('/Users/felicity/PycharmProjects/MisinfoPy/results/open_exploration_all_SAMPLE')
exp, out = results

sns.set_style("whitegrid")
fig, axes = pairs_plotting.pairs_scatter(
    exp, out, group_by="policy", legend=True,
)
fig.set_size_inches(16, 16)
plt.show()

# %%
# Indiv Max (SIT)
results = load_results('/Users/felicity/PycharmProjects/MisinfoPy/results/open_exploration_all_SIT')
exp, out = results

sns.set_style("whitegrid")
fig, axes = pairs_plotting.pairs_scatter(
    exp, out, group_by="policy", legend=True,
)
fig.set_size_inches(16, 16)
plt.show()

# %%
# # Indiv Max (DEFFUANT)
# results = load_results('/Users/felicity/PycharmProjects/MisinfoPy/results/open_exploration_indiv_DEFFUANT')
# exp, out = results
#
# sns.set_style("whitegrid")
# fig, axes = pairs_plotting.pairs_scatter(
#     exp, out, group_by="policy", legend=True,
# )
# fig.set_size_inches(16, 16)
# plt.show()
